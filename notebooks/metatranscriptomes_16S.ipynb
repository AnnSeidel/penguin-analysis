# %%
# Notebook to generate 16S rRNA assembly analysis for the Penguin paper

# %%
import sys, os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
label_dic={"penguin":"PenguiN",
           "megahit":"Megahit",
           "metaspades":"metaSPAdes",
           "metaviralspades":"metaviralSPAdes",
           "rnaspades":"rnaSPAdes",
           "rnaviralspades": "rnaviralSPAdes",
           "iva":"IVA",
           "vicuna": "VICUNA",
           "savage": "SAVAGE",
           "haploflow":"Haploflow"
          }

color_dic={"penguin":'#EE8866',
           "megahit":'#EEDD88',
           "metaspades":'#77AADD',
           "metaviralspades":'#FFAABB',
           "rnaspades":'#99DDFF',
           "rnaviralspades":'#44BB99',
           "iva":'#D6E465',
           "vicuna": '#DDDDDD',
           "savage": '#a38995',
           "haploflow": '#AAAA00'
        }


color2Label={label_dic[label]:color_dic[label] for label in label_dic}

# %%
plt.rcParams["font.size"] = 6
DPI=300

# %%
outDir="../figures/"

if not os.path.exists(outDir):
    os.mkdir(outDir)

# %% [markdown]
# # Figure 7

# %%
figureSize=(8.3/2.54, 5.3/2.54)

def numfmt(x, pos):
    if x>0:
        s = '{:d}k'.format(int(x // 1000))
    else:
        s = '{:d}'.format(int(x))
    return s

import matplotlib.ticker as tkr
xfmt = tkr.FuncFormatter(numfmt)

# %%
# Figure 7 A

def plot_horizontal_50perccov_99clust(ax):
    assemblers0 = ("penguin", "megahit", "metaspades", "rnaspades",
     "rnaviralspades", "iva", "vicuna", "haploflow")
    assemblers = [label_dic[key] for key in assemblers0]
    rrnas_counts = (113196, 9123, 1713, 18933, 3203, 229, 2028, 1059)

    ax.barh(assemblers, rrnas_counts, align='center',
     color=[color_dic[key] for key in assemblers0])
    ax.invert_yaxis()
    ax.set_xlabel('Nonredundant assembled 16S rRNA contigs')
    #ax.tick_params(axis='both', which='major', labelsize=8)
    #ax.tick_params(axis='both', which='minor', labelsize=8)
    #ax.patch.set_edgecolor('black')
    #ax.patch.set_linewidth(1)

    #ax.xaxis.set_ticks(np.array([0, 20000, 50000, 70000, 100000]))
    ax.set_xlim(0, 120000)
fig=plt.figure()
#Set size
plot_horizontal_50perccov_99clust(plt.gca())
plt.gca().xaxis.set_major_formatter(xfmt)
fig.set_size_inches(figureSize)
fig.tight_layout()
plt.savefig(outDir + "Fig_7_A.png", dpi=DPI, transparent=True)

# %%
# Figure 7 B
def plot_horizontal_silva_80perccov_99clust_silva50(ax):

    assemblers0 = ("penguin", "megahit", "metaspades", "rnaspades",
     "rnaviralspades", "iva", "vicuna", "haploflow")
    assemblers = [label_dic[key] for key in assemblers0]
    rrnas_counts = (15802, 1698, 433, 1650, 871, 61, 561, 65)

    ax.barh(assemblers, rrnas_counts, align='center',
     color=[color_dic[key] for key in assemblers0], linewidth=10)
    ax.invert_yaxis()
    ax.tick_params(labelleft=False)
    ax.set_xlabel('Nonredundant assembled 16S rRNA contigs')

    #ax.xaxis.set_ticks(np.array([0, 20000, 50000, 70000, 100000]))
    ax.set_xlim(0, 17000)

fig=plt.figure()
#Set size
plot_horizontal_silva_80perccov_99clust_silva50(plt.gca())
plt.gca().xaxis.set_major_formatter(xfmt)
fig.set_size_inches(figureSize)
fig.tight_layout()
plt.savefig(outDir + "Fig_7_B.png", dpi=DPI, transparent=True)

# %%
# Figure 7 C

def plot_horizontal_silva_50perccov_99clust_silva80(ax):

    assemblers0 = ("penguin", "megahit", "metaspades", "rnaspades",
     "rnaviralspades", "iva", "vicuna", "haploflow")
    assemblers = [label_dic[key] for key in assemblers0]
    rrnas_counts = (5102, 586, 117, 461, 238, 22, 226, 24)

    ax.barh(assemblers, rrnas_counts, align='center',
     color=[color_dic[key] for key in assemblers0])
    ax.invert_yaxis()
    ax.set_xlabel('Nonredundant assembled 16S rRNA contigs')

    #ax.xaxis.set_ticks(np.array([0, 20000, 50000, 70000, 100000]))
    ax.set_xlim(0, 5500)#

fig=plt.figure()
#Set size
plot_horizontal_silva_50perccov_99clust_silva80(plt.gca())
plt.gca().xaxis.set_major_formatter(xfmt)
fig.set_size_inches(figureSize)
fig.tight_layout()
plt.savefig(outDir + "Fig_7_C.png", dpi=DPI, transparent=True)

# %%
# Figure 7 D

def plot_horizontal_50perccov_99clust_silva95(ax):

    assemblers0 = ("penguin", "megahit", "metaspades", "rnaspades",
     "rnaviralspades", "iva", "vicuna", "haploflow")
    assemblers = [label_dic[key] for key in assemblers0]
    rrnas_counts = (2284, 269, 49, 216, 110, 14, 126, 5)

    ax.barh(assemblers, rrnas_counts, align='center',
     color=[color_dic[key] for key in assemblers0])
    ax.invert_yaxis()
    ax.tick_params(labelleft=False)
    ax.set_xlabel('Nonredundant assembled 16S rRNA contigs')
    ax.set_xlim(0, 2500)

fig=plt.figure()
#Set size
plot_horizontal_50perccov_99clust_silva95(plt.gca())

plt.gca().xaxis.set_major_formatter(xfmt)
fig.set_size_inches(figureSize)
fig.tight_layout()
plt.savefig(outDir + "Fig_7_D.png", dpi=DPI, transparent=True)

# %% [markdown]
# # Figure 8

# %%
rrnas_counts = {
    "PenguiN": (59538,32169,18565,12616,9136,6921,5412,4376,3519,3034,2551,642,355,306,275),
    "Megahit" : (3737,2533,2256,2059,1886,1766,1621,1465,1350,1225,1091,282,141,140,137),
    "metaSPAdes" : (471,322,297,269,257,251,250,245,237,232,225,134,93,87,85),
    "rnaSPAdes" : (8154,5132,3814,3068,2568,2192,1876,1632,1443,1251,1087,287,152,145,145),
    "rnaviralSPAdes": (1132,628,546,515,500,477,464,458,444,429,418,183,106,106,96),
    "IVA": (140,117,104,98,89,80,69,67,60,48,45,23,9,11,11),
    "VICUNA": (1074,837,746,679,620,577,536,498,465,435,398,123,53,54,52),
    "Haploflow": (337, 323, 317, 309, 302, 291, 284, 275, 269, 257, 245, 74, 34, 29, 28)
}

clustering_levels = [100,99,98,97,96,95,94,93,92,91,90,80,70,60,50]

counts = {'T': ['PenguiN', 'Megahit', 'metaSPAdes', 'rnaSPAdes', 'rnaviralSPAdes', 'IVA', 'VICUNA', 'Haploflow'],
        'C': [(100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50),
                          (100,99,98,97,96,95,94,93,92,91,90,80,70,60,50)],
          'N': [(59538,32169,18565,12616,9136,6921,5412,4376,3519,3034,2551,642,355,306,275),
                                  (3737,2533,2256,2059,1886,1766,1621,1465,1350,1225,1091,282,141,140,137),
                                  (471,322,297,269,257,251,250,245,237,232,225,134,93,87,85),
                                  (8154,5132,3814,3068,2568,2192,1876,1632,1443,1251,1087,287,152,145,145),
                                  (1132,628,546,515,500,477,464,458,444,429,418,183,106,106,96),
                                  (140,117,104,98,89,80,69,67,60,48,45,23,9,11,11),
                                  (1074,837,746,679,620,577,536,498,465,435,398,123,53,54,52),
                                  (337, 323, 317, 309, 302, 291, 284, 275, 269, 257, 245, 74, 34, 29, 28)]}

df_cluster_stats = pd.DataFrame(counts)
df_cluster_stats = df_cluster_stats.explode(list('CN'))
df_cluster_stats.columns = ['Tool', 'Cluster SeqId', 'Num Representatives']

# %%
plt.figure(figsize=(7.76/2.54,5/2.54), dpi=300)

ax=sns.lineplot(data=df_cluster_stats, x="Cluster SeqId", y="Num Representatives", hue="Tool",\
             marker="o",palette=color2Label, linewidth=0.5, markersize=3)


plt.legend(title="",frameon=False)
plt.xlabel("Sequence Identity (%)")
plt.ylabel("Number of RdRp clusters")
plt.gca().invert_xaxis()


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig(outDir + 'Fig_8.png', dpi=DPI, transparent=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 plt.figure(figsize=(7.76/2.54,5/2.54), dpi=300)
# ----> 3 ax=sns.lineplot(data=df_cluster_stats, x="Cluster SeqId", y="Num Representatives", hue="Tool",\
#       4              marker="o",palette=color2Label, linewidth=0.5, markersize=3)
#       7 plt.legend(title="",frameon=False)
#       8 plt.xlabel("Sequence Identity (%)")
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/relational.py:471, in _LinePlotter.plot(self, ax, kws)
#     469 # Loop over the semantic subsets and add to the plot
#     470 grouping_vars = "hue", "size", "style"
# --> 471 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     473     if self.sort:
#     474         sort_vars = ["units", "x", "y"]
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/_core.py:983, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data)
#     978 grouping_vars = [
#     979     var for var in grouping_vars if var in self.variables
#     980 ]
#     982 if from_comp_data:
# --> 983     data = self.comp_data
#     984 else:
#     985     data = self.plot_data
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/_core.py:1057, in VectorPlotter.comp_data(self)
#    1055     orig = self.plot_data[var].dropna()
#    1056 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1059 if axis.get_scale() == "log":
#    1060     comp_col = np.log10(comp_col)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:723, in _LocationIndexer.__setitem__(self, key, value)
#     720 self._has_valid_setitem_indexer(key)
#     722 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:1732, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1730     self._setitem_with_indexer_split_path(indexer, value, name)
#    1731 else:
# -> 1732     self._setitem_single_block(indexer, value, name)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:1959, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    1954     indexer = maybe_convert_ix(*indexer)
#    1955 if (isinstance(value, ABCSeries) and name != "iloc") or isinstance(value, dict):
#    1956     # TODO(EA): ExtensionBlock.setitem this causes issues with
#    1957     # setting for extensionarrays that store dicts. Need to decide
#    1958     # if it's worth supporting that.
# -> 1959     value = self._align_series(indexer, Series(value))
#    1961 elif isinstance(value, ABCDataFrame) and name != "iloc":
#    1962     value = self._align_frame(indexer, value)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexing.py:2096, in _iLocIndexer._align_series(self, indexer, ser, multiindex_indexer)
#    2093 # we have a frame, with multiple indexers on both axes; and a
#    2094 # series, so need to broadcast (see GH5206)
#    2095 if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -> 2096     ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2098     # single indexer
#    2099     if len(indexer) > 1 and not multiindex_indexer:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/series.py:4580, in Series.reindex(self, index, **kwargs)
#    4572 @doc(
#    4573     NDFrame.reindex,  # type: ignore[has-type]
#    4574     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4578 )
#    4579 def reindex(self, index=None, **kwargs):
# -> 4580     return super().reindex(index=index, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:4818, in NDFrame.reindex(self, *args, **kwargs)
#    4815     return self._reindex_multi(axes, copy, fill_value)
#    4817 # perform the reindex on the axes
# -> 4818 return self._reindex_axes(
#    4819     axes, level, limit, tolerance, method, fill_value, copy
#    4820 ).__finalize__(self, method="reindex")
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:4839, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4834     new_index, indexer = ax.reindex(
#    4835         labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4836     )
#    4838     axis = self._get_axis_number(a)
# -> 4839     obj = obj._reindex_with_indexers(
#    4840         {axis: [new_index, indexer]},
#    4841         fill_value=fill_value,
#    4842         copy=copy,
#    4843         allow_dups=False,
#    4844     )
#    4846 return obj
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py:4883, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4880     indexer = ensure_platform_int(indexer)
#    4882 # TODO: speed up on homogeneous DataFrame objects
# -> 4883 new_data = new_data.reindex_indexer(
#    4884     index,
#    4885     indexer,
#    4886     axis=baxis,
#    4887     fill_value=fill_value,
#    4888     allow_dups=allow_dups,
#    4889     copy=copy,
#    4890 )
#    4891 # If we've made a copy once, no need to make another one
#    4892 copy = False
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/internals/managers.py:670, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668 # some axes don't allow reindexing with dups
#     669 if not allow_dups:
# --> 670     self.axes[axis]._validate_can_reindex(indexer)
#     672 if axis >= self.ndim:
#     673     raise IndexError("Requested axis not found in manager")
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexes/base.py:3785, in Index._validate_can_reindex(self, indexer)
#    3783 # trying to reindex on an axis with duplicates
#    3784 if not self._index_as_unique and len(indexer):
# -> 3785     raise ValueError("cannot reindex from a duplicate axis")
#
# ValueError: cannot reindex from a duplicate axis
